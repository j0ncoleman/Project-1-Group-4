# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import hvplot.pandas
import os
from pathlib import Path
from dotenv import load_dotenv
from panel.interact import interact
from datetime import datetime

# %matplotlib inline

# %%
filepath1 = Path("C:/Users/ritvi/OneDrive/Documents/# UofT FinTech Course/Project 1/Crunchbase Data.csv")
crunchbase_data = pd.read_csv(filepath1, parse_dates=[0])
crunchbase_data["Announced Date"] = pd.to_datetime(crunchbase_data["Announced Date"])
crunchbase_data["Announced Year"] = crunchbase_data['Announced Date'].dt.year
crunchbase_data = crunchbase_data.set_index("Sl. No.")

crunchbase_data.head()
crunchbase_data.head(-5)
# Out:
#                                           Transaction Name  \
# Sl. No.
# 1                                         Series C - Nesto
# 2                         Private Equity Round - Pomerleau
# 3        Private Equity Round - Wilkar Property Management
# 4                                Grant - Mero Technologies
# 5           Private Equity Round - TSE Management Services
# ...                                                    ...
# 532                               Post-IPO Equity - RioCan
# 533                   Post-IPO Equity - Aston Bay Holdings
# 534                       Post-IPO Equity - Mosaic Capital
# 535                                 Seed Round - Spark CRM
# 536                            Angel Round - Envio Systems
#
#                                      Organization Industry  \
# Sl. No.
# 1                 Financial Services, FinTech, Real Estate
# 2                        Construction, Energy, Real Estate
# 3                         Property Management, Real Estate
# 4        Analytics, Internet of Things, Real Estate, So...
# 5                         Property Management, Real Estate
# ...                                                    ...
# 532                  Leasing, Real Estate, Rental Property
# 533                   Mining, Precious Metals, Real Estate
# 534       Banking, Insurance, Real Estate, Venture Capital
# 535                  CRM, Marketing, Real Estate, Software
# 536      Cloud Management, Energy, Energy Efficiency, E...
#
#                                      Organization Location     Funding Type  \
# Sl. No.
# 1                  Montreal, Quebec, Canada, North America         Series C
# 2                    Quebec, Quebec, Canada, North America   Private Equity
# 3                 Westmount, Quebec, Canada, North America   Private Equity
# 4                  Toronto, Ontario, Canada, North America            Grant
# 5            Richmond Hill, Ontario, Canada, North America   Private Equity
# ...                                                    ...              ...
# 532                Toronto, Ontario, Canada, North America  Post-IPO Equity
# 533                Toronto, Ontario, Canada, North America  Post-IPO Equity
# 534                Calgary, Alberta, Canada, North America  Post-IPO Equity
# 535      Vancouver, British Columbia, Canada, North Ame...             Seed
# 536                Calgary, Alberta, Canada, North America            Angel
#
#          Money Raised Announced Date  Announced Year      Funding Status  \
# Sl. No.
# 1          80000000.0     2022-12-13            2022  Late Stage Venture
# 2         150000000.0     2022-12-07            2022      Private Equity
# 3                 NaN     2022-12-07            2022      Private Equity
# 4           1500000.0     2023-01-10            2023                 NaN
# 5                 NaN     2022-12-07            2022      Private Equity
# ...               ...            ...             ...                 ...
# 532       230000000.0     2019-10-28            2019                 NaN
# 533               NaN     2018-04-26            2018                 NaN
# 534        28776336.0     2014-06-20            2014                 NaN
# 535          150000.0     2014-06-25            2014                Seed
# 536         1200000.0     2016-11-13            2016                Seed
#
#          Total Funding Amount
# Sl. No.
# 1                 151354383.0
# 2                 200000000.0
# 3                         NaN
# 4                   4800000.0
# 5                         NaN
# ...                       ...
# 532               680000000.0
# 533                  109802.0
# 534                54193256.0
# 535                 6101978.0
# 536                 6216736.0
#
# [536 rows x 9 columns]

# %%
print(crunchbase_data["Money Raised"].dtype)
# Out:
# float64

# %%
Money_Raised = crunchbase_data[["Announced Year", "Money Raised"]]
Money_Raised.head(15)
# Out:
#          Announced Year  Money Raised
# Sl. No.
# 1                  2022    80000000.0
# 2                  2022   150000000.0
# 3                  2022           NaN
# 4                  2023     1500000.0
# 5                  2022           NaN
# 6                  2022     5500000.0
# 7                  2022    36000000.0
# 8                  2022     4000000.0
# 9                  2022     2550000.0
# 10                 2022    22000000.0
# 11                 2022     8000000.0
# 12                 2018    50000000.0
# 13                 2022     8100000.0
# 14                 2022           NaN
# 15                 2022       25000.0

# %%
Money_Raised = Money_Raised.dropna().copy()
Money_Raised["Money Raised"] = Money_Raised["Money Raised"].div(10000).round(2)
Money_Raised.head(15)
# Out:
#          Announced Year  Money Raised
# Sl. No.
# 1                  2022        8000.0
# 2                  2022       15000.0
# 4                  2023         150.0
# 6                  2022         550.0
# 7                  2022        3600.0
# 8                  2022         400.0
# 9                  2022         255.0
# 10                 2022        2200.0
# 11                 2022         800.0
# 12                 2018        5000.0
# 13                 2022         810.0
# 15                 2022           2.5
# 16                 2022           2.5
# 17                 2022           2.5
# 18                 2022         220.0

# %%
Money_Raised_Grouped = Money_Raised.groupby("Announced Year")["Money Raised"].sum()
Money_Raised_Grouped.head(20)
# Out:
# Announced Year
# 2000       300.00
# 2006       222.41
# 2007       910.00
# 2008      2850.00
# 2009        88.91
# 2010       475.00
# 2011      9929.32
# 2012      4277.38
# 2013     37287.35
# 2014     29869.23
# 2015     38436.54
# 2016     61152.64
# 2017     97195.85
# 2018    162522.43
# 2019     89120.70
# 2020     57508.74
# 2021    124141.28
# 2022     70879.87
# 2023       150.00
# Name: Money Raised, dtype: float64

# %%
Money_Raised_Grouped.plot(kind='bar', stacked=False)
# Out:
# <AxesSubplot:xlabel='Announced Year'>

# %%
Money_Raised2 = crunchbase_data[["Announced Year", "Money Raised","Funding Status"]]
Money_Raised2 = Money_Raised2.dropna().copy()
Money_Raised2["Money Raised"] = Money_Raised2["Money Raised"].div(10000).round(2)
Money_Raised2.head(15)
# Out:
#          Announced Year  Money Raised       Funding Status
# Sl. No.
# 1                  2022        8000.0   Late Stage Venture
# 2                  2022       15000.0       Private Equity
# 6                  2022         550.0                 Seed
# 7                  2022        3600.0  Early Stage Venture
# 8                  2022         400.0  Early Stage Venture
# 9                  2022         255.0                 Seed
# 10                 2022        2200.0  Early Stage Venture
# 12                 2018        5000.0       Private Equity
# 13                 2022         810.0  Early Stage Venture
# 18                 2022         220.0                 Seed
# 19                 2022         260.0                 Seed
# 21                 2022         120.0                 Seed
# 22                 2022         600.0  Early Stage Venture
# 23                 2017          30.0                 Seed
# 24                 2021        4400.0  Early Stage Venture

# %%
Money_Raised_Grouped2 = Money_Raised2.groupby(["Announced Year","Funding Status"])["Money Raised"].sum().unstack().plot(kind='bar', stacked=True)

# %%
filepath2 = Path("C:/Users/ritvi/OneDrive/Documents/# UofT FinTech Course/Project 1/New Housing Developments Data.csv")
New_Developments = pd.read_csv(filepath2,)

New_Developments.head()
# Out:
#    Year Quarter  New Housing Stats
# 0  2002      Q1              36140
# 1  2002      Q2              59160
# 2  2002      Q3              55730
# 3  2002      Q4              54004
# 4  2003      Q1              38270

# %%
New_Developments.groupby(['Year', 'Quarter']).sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
filepath3 = Path("C:/Users/ritvi/OneDrive/Documents/# UofT FinTech Course/Project 1/Resident and Non-Resident Ownership.csv")
rvnr = pd.read_csv(filepath3,)

rvnr.head()
# Out:
#        Geography  Ownership type Residency status      2020
# 0    Nova Scotia      Individual         Resident  455530.0
# 1    Nova Scotia      Individual     Non-resident   27630.0
# 2    Nova Scotia  Non-individual         Resident    8965.0
# 3    Nova Scotia  Non-individual     Non-resident     220.0
# 4  New Brunswick      Individual         Resident  381770.0

# %%
filepath4 = Path("C:/Users/ritvi/OneDrive/Documents/# UofT FinTech Course/Project 1/Owned Vs Rented Property.csv")
rentvown= pd.read_csv(filepath4,)
rentvown= rentvown.set_index('Year')

rentvown.head()
# Out:
#         Owned   Rented
# Year
# 2011  9185845  4078230
# 2016  9541320  4474535
# 2021  9955970  4953835

# %%
rentvown.plot(kind='bar', stacked=True, title="Census Canada: Owned Vs Rented Property")
# Out:
# <AxesSubplot:title={'center':'Census Canada: Owned Vs Rented Property'}, xlabel='Year'>

# %%
rentvown_group2 = rentvown.groupby("Ownership").sum()
plt.plot(
